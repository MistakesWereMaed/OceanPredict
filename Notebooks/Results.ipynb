# %%
import data_visualization as dv
import xarray as xr

PATH_RESULTS_PINN = "../Results/PINN.nc"
PATH_RESULTS_GNN = "../Results/GNN.nc"
PATH_RESULTS_FNO = "../Results/FNO.nc"

pinn = xr.open_dataset(PATH_RESULTS_GNN)
gnn = xr.open_dataset(PATH_RESULTS_FNO)
fno = xr.open_dataset(PATH_RESULTS_PINN)

dv.plot_currents(pinn)
dv.plot_currents(gnn)
dv.plot_currents(fno)
