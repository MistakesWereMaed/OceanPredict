# %%
import data_visualization as dv
import xarray as xr

PATH_RESULTS_PINN = "../Models/PINN/results.nc"
PATH_RESULTS_GNN = "../Models/GNN/results.nc"
PATH_RESULTS_FNO = "../Models/FNO/results.nc"

# %%
pinn = xr.open_dataset(PATH_RESULTS_PINN)
dv.plot_currents(pinn, time_idx=5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/Lightning/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/.conda/envs/Lightning/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/nhn479/Projects/OceanPredict/Models/PINN/results.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '89370cc0-9a6d-4e45-9c49-1a3b5b7bff0c']
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
gnn = xr.open_dataset(PATH_RESULTS_GNN)
dv.plot_currents(gnn)
# Out:
# 0.6807724

# %%
fno = xr.open_dataset(PATH_RESULTS_FNO)
dv.plot_currents(fno, time_idx=0)
# Out:
# Loss at time index 0 0.5673059
